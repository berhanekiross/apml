# %%
# Let's first load and preview the data from the uploaded SerieA.csv file
import pandas as pd
import numpy as np
from collections import defaultdict
from scipy.stats import truncnorm
from scipy.stats import norm

# Path to the uploaded file
file_path = 'SerieA.csv'

# Load the data
serie_a_data = pd.read_csv(file_path)

# Preview the first few rows of the dataset
serie_a_data.head()
# Out:
#    yyyy-mm-dd  HH:MM     team1     team2  score1  score2
# 0  2018-08-18  18:00    Chievo  Juventus       2       3
# 1  2018-08-18  20:30     Lazio    Napoli       1       2
# 2  2018-08-19  18:00    Torino      Roma       0       1
# 3  2018-08-19  20:30  Sassuolo     Inter       1       0
# 4  2018-08-19  20:30     Parma   Udinese       2       2

# %%
# Initialize player skills as Gaussian (mean = 25, std = 8)
initial_mean = 25
initial_std = 8

# Define a dictionary to hold player skills
player_skills = defaultdict(lambda: np.random.normal(initial_mean, initial_std))

# Function to update player skills based on match result
def update_skills(player1, player2, score1, score2):
    skill1 = player_skills[player1]
    skill2 = player_skills[player2]
    
    # Compute outcome difference as Gaussian random variable
    outcome = np.random.normal(skill1 - skill2, 1)  # Outcome difference with some noise
    
    # Determine match result based on the outcome
    if score1 > score2:
        result = 1  # Player 1 wins
    elif score1 < score2:
        result = -1  # Player 2 wins
    else:
        result = 0  # Draw
    
    # Update skills using a simple adjustment (we can expand this later for full Bayesian update)
    k = 0.1  # Learning rate for skill adjustment
    if result == 1:
        player_skills[player1] += k * (skill2 - skill1)
        player_skills[player2] -= k * (skill2 - skill1)
    elif result == -1:
        player_skills[player2] += k * (skill1 - skill2)
        player_skills[player1] -= k * (skill1 - skill2)

# Apply skill updates based on all matches in the dataset
for idx, row in serie_a_data.iterrows():
    team1, team2 = row['team1'], row['team2']
    score1, score2 = row['score1'], row['score2']
    update_skills(team1, team2, score1, score2)

# Display a few player skills after the update
updated_skills = {player: skill for player, skill in list(player_skills.items())[:10]}
updated_skills
# Out:
# {'Chievo': 26.84560877370682,
#  'Juventus': 25.871860198072792,
#  'Lazio': 25.653454424420996,
#  'Napoli': 25.90114666043628,
#  'Torino': 26.377327391988484,
#  'Roma': 25.272950347010422,
#  'Sassuolo': 25.2042760526244,
#  'Inter': 25.559633397798223,
#  'Parma': 25.31929244482015,
#  'Udinese': 25.83246006095596}

# %%
# Function to compute truncated Gaussian distribution p(t | s1, s2, y)
def truncated_gaussian(skill1, skill2, result):
    mean_diff = skill1 - skill2
    std_dev = 1  # Assumed standard deviation for the outcome variable

    # If Player 1 wins (y = 1), we truncate the Gaussian to values greater than 0
    if result == 1:
        a, b = 0, np.inf  # Truncate to (0, ∞)
    elif result == -1:
        a, b = -np.inf, 0  # Truncate to (-∞, 0)
    else:
        a, b = -np.inf, np.inf  # No truncation for a draw

    # Truncated Gaussian distribution
    truncated_gaussian_dist = truncnorm(a=(a - mean_diff) / std_dev, b=(b - mean_diff) / std_dev, loc=mean_diff, scale=std_dev)
    return truncated_gaussian_dist

# Example: Let's compute the truncated Gaussian for a match between Chievo and Juventus where Chievo lost
team1 = 'Chievo'
team2 = 'Juventus'
score1 = 2
score2 = 3
result = 1 if score1 > score2 else -1

# Get the current skills of the teams
skill1 = player_skills[team1]
skill2 = player_skills[team2]

# Compute the truncated Gaussian distribution for this match
trunc_gauss_dist = truncated_gaussian(skill1, skill2, result)

# Compute mean and variance of the truncated distribution
truncated_mean = trunc_gauss_dist.mean()
truncated_variance = trunc_gauss_dist.var()

truncated_mean, truncated_variance
# Out:
# (np.float64(-0.5304024039828856), np.float64(0.2021947044579756))

# %%
# Function to compute the marginal probability that Player 1 wins (p(y = 1))
def prob_player1_wins(skill1, skill2):
    mean_diff = skill1 - skill2
    std_dev = 1  # Standard deviation for outcome variable

    # The probability that Player 1 wins is the probability that t > 0
    # Where t ~ N(s1 - s2, 1), hence we calculate P(t > 0)
    prob_win = 1 - norm.cdf(0, loc=mean_diff, scale=std_dev)
    return prob_win

# Compute the probability that Chievo wins against Juventus
prob_chievo_wins = prob_player1_wins(skill1, skill2)
prob_chievo_wins
# Out:
# np.float64(0.8349093039972402)

# %%
import pandas as pd
import numpy as np
from scipy.stats import truncnorm, norm

# Load the dataset
data = pd.read_csv('SerieA.csv')

# Initializing player skills, assuming all players start with a mean skill of 25 and standard deviation of 8
players = pd.concat([data['team1'], data['team2']]).unique()
player_skills = {player: {'mean': 25, 'std': 8} for player in players}

# Data processing to simplify the game outcomes
data['result'] = np.where(data['score1'] > data['score2'], 1, -1)  # Player 1 wins if score1 > score2, else Player 2 wins

# %%
def update_skills(player1, player2, result, player_skills, outcome_var=1):
    skill1 = player_skills[player1]
    skill2 = player_skills[player2]
    
    mean_diff = skill1['mean'] - skill2['mean']
    std_diff = np.sqrt(skill1['std']**2 + skill2['std']**2 + outcome_var)

    # If player 1 wins, we truncate to t > 0, otherwise to t < 0
    if result == 1:
        a, b = 0, np.inf  # Truncate the distribution for player 1 winning
    else:
        a, b = -np.inf, 0  # Truncate the distribution for player 2 winning
    
    # Truncated Gaussian distribution for the match outcome
    trunc_gauss_dist = truncnorm(a=(a - mean_diff) / std_diff, b=(b - mean_diff) / std_diff, loc=mean_diff, scale=std_diff)
    
    # Update player skills based on the match outcome
    outcome_mean = trunc_gauss_dist.mean()
    skill1_update = skill1['mean'] + outcome_mean * (skill1['std']**2) / (skill1['std']**2 + skill2['std']**2)
    skill2_update = skill2['mean'] - outcome_mean * (skill2['std']**2) / (skill1['std']**2 + skill2['std']**2)
    
    player_skills[player1]['mean'] = skill1_update
    player_skills[player2]['mean'] = skill2_update

    return player_skills

# %%
def prob_player1_wins(skill1, skill2):
    mean_diff = skill1['mean'] - skill2['mean']
    std_diff = np.sqrt(skill1['std']**2 + skill2['std']**2)
    
    # The probability of Player 1 winning is P(t > 0)
    return 1 - norm.cdf(0, loc=mean_diff, scale=std_diff)

# Example usage for a specific match
team1 = 'Chievo'
team2 = 'Juventus'

# Compute the probability of Chievo winning
prob_chievo_wins = prob_player1_wins(player_skills[team1], player_skills[team2])
print(f"Probability of {team1} winning against {team2}: {prob_chievo_wins:.4f}")
# Out:
# Probability of Chievo winning against Juventus: 0.5000

# %%
for _, row in data.iterrows():
    team1 = row['team1']
    team2 = row['team2']
    result = row['result']
    
    # Update player skills based on the result of the match
    player_skills = update_skills(team1, team2, result, player_skills)
    
    # Optionally, print the updated skills after each match
    print(f"Updated skills: {team1} = {player_skills[team1]['mean']:.2f}, {team2} = {player_skills[team2]['mean']:.2f}")
# Out:
# Updated skills: Chievo = 20.47, Juventus = 29.53
# Updated skills: Lazio = 20.47, Napoli = 29.53
# Updated skills: Torino = 20.47, Roma = 29.53
# Updated skills: Sassuolo = 29.53, Inter = 20.47
# Updated skills: Parma = 20.47, Udinese = 29.53
# Updated skills: Empoli = 29.53, Cagliari = 20.47
# Updated skills: Bologna = 20.47, Spal = 29.53
# Updated skills: Atalanta = 29.53, Frosinone = 20.47
# Updated skills: Juventus = 36.15, Lazio = 13.85
# Updated skills: Napoli = 34.99, Milan = 19.54
# Updated skills: Spal = 36.15, Parma = 13.85
# Updated skills: Udinese = 34.99, Sampdoria = 19.54
# Updated skills: Inter = 15.94, Torino = 25.00
# Updated skills: Genoa = 28.80, Empoli = 25.73
# Updated skills: Frosinone = 15.94, Bologna = 25.00
# Updated skills: Fiorentina = 30.46, Chievo = 15.01
# Updated skills: Cagliari = 13.85, Sassuolo = 36.15
# Updated skills: Roma = 25.00, Atalanta = 34.06
# Updated skills: Milan = 23.21, Roma = 21.33
# Updated skills: Bologna = 21.78, Inter = 19.16
# Updated skills: Parma = 2.35, Juventus = 47.65
# Updated skills: Fiorentina = 34.26, Udinese = 31.19
# Updated skills: Torino = 28.00, Spal = 33.15
# Updated skills: Sassuolo = 42.31, Genoa = 22.64
# Updated skills: Sampdoria = 22.15, Napoli = 32.38
# Updated skills: Lazio = 18.02, Frosinone = 11.77
# Updated skills: Chievo = 7.89, Empoli = 32.85
# Updated skills: Atalanta = 31.79, Cagliari = 16.12
# Updated skills: Inter = 16.65, Parma = 4.86
# Updated skills: Napoli = 36.58, Fiorentina = 30.05
# Updated skills: Frosinone = 4.75, Sampdoria = 29.17
# Updated skills: Roma = 18.54, Chievo = 10.68
# Updated skills: Udinese = 27.19, Torino = 32.00
# Updated skills: Juventus = 53.30, Sassuolo = 36.66
# Updated skills: Genoa = 27.34, Bologna = 17.08
# Updated skills: Empoli = 30.18, Lazio = 20.68
# Updated skills: Cagliari = 10.03, Milan = 29.30
# Updated skills: Spal = 37.94, Atalanta = 27.00
# Updated skills: Sampdoria = 24.47, Fiorentina = 34.75
# Updated skills: Sassuolo = 42.59, Empoli = 24.25
# Updated skills: Parma = 8.57, Cagliari = 6.32
# Updated skills: Fiorentina = 38.75, Spal = 33.94
# Updated skills: Sampdoria = 21.10, Inter = 20.02
# Updated skills: Torino = 26.53, Napoli = 42.05
# Updated skills: Lazio = 24.20, Genoa = 23.82
# Updated skills: Chievo = 1.57, Udinese = 36.30
# Updated skills: Bologna = 21.36, Roma = 14.27
# Updated skills: Milan = 25.16, Atalanta = 31.14
# Updated skills: Frosinone = -19.52, Juventus = 77.57
# Updated skills: Inter = 22.39, Fiorentina = 36.38
# Updated skills: Udinese = 33.39, Lazio = 27.10
# Updated skills: Roma = 31.19, Frosinone = -36.44
# Updated skills: Napoli = 58.82, Parma = -8.20
# Updated skills: Juventus = 105.67, Bologna = -6.75
# Updated skills: Genoa = 35.29, Chievo = -9.89
# Updated skills: Cagliari = -2.15, Sampdoria = 29.57
# Updated skills: Atalanta = 27.35, Torino = 30.32
# Updated skills: Spal = 27.43, Sassuolo = 49.10
# Updated skills: Empoli = 19.55, Milan = 29.86
# Updated skills: Roma = 36.55, Lazio = 21.75
# Updated skills: Juventus = 129.10, Napoli = 35.40
# Updated skills: Inter = 34.89, Cagliari = -14.64
# Updated skills: Bologna = -5.33, Udinese = 31.97
# Updated skills: Frosinone = -72.30, Genoa = 71.15
# Updated skills: Fiorentina = 42.99, Atalanta = 20.74
# Updated skills: Chievo = -30.00, Torino = 50.43
# Updated skills: Parma = -6.34, Empoli = 17.69
# Updated skills: Sassuolo = 46.76, Milan = 32.19
# Updated skills: Sampdoria = 34.51, Spal = 22.49
# Updated skills: Torino = 111.79, Frosinone = -133.67
# Updated skills: Cagliari = -11.44, Bologna = -8.53
# Updated skills: Udinese = -16.59, Juventus = 177.66
# Updated skills: Empoli = 7.66, Roma = 46.58
# Updated skills: Genoa = 70.35, Parma = -5.54
# Updated skills: Milan = 63.29, Chievo = -61.10
# Updated skills: Lazio = 23.95, Fiorentina = 40.78
# Updated skills: Atalanta = 12.63, Sampdoria = 42.62
# Updated skills: Napoli = 38.38, Sassuolo = 43.78
# Updated skills: Spal = 14.85, Inter = 42.53
# Updated skills: Roma = 44.88, Spal = 16.54
# Updated skills: Juventus = 177.07, Genoa = 70.94
# Updated skills: Udinese = -44.07, Napoli = 65.86
# Updated skills: Frosinone = -204.33, Empoli = 78.32
# Updated skills: Parma = -20.36, Lazio = 38.78
# Updated skills: Chievo = -97.96, Atalanta = 49.50
# Updated skills: Bologna = -68.68, Torino = 171.95
# Updated skills: Fiorentina = 39.64, Cagliari = -10.31
# Updated skills: Inter = 44.77, Milan = 61.05
# Updated skills: Sampdoria = 37.87, Sassuolo = 48.53
# Updated skills: Atalanta = 84.43, Parma = -55.29
# Updated skills: Empoli = 28.95, Juventus = 226.44
# Updated skills: Torino = 171.47, Fiorentina = 40.12
# Updated skills: Sassuolo = 47.99, Bologna = -68.14
# Updated skills: Spal = 16.25, Frosinone = -204.04
# Updated skills: Genoa = 70.39, Udinese = -43.52
# Updated skills: Cagliari = 33.52, Chievo = -141.79
# Updated skills: Milan = 72.93, Sampdoria = 25.99
# Updated skills: Napoli = 63.64, Roma = 47.10
# Updated skills: Lazio = 32.97, Inter = 50.58
# Updated skills: Milan = 77.96, Genoa = 65.37
# Updated skills: Napoli = 81.01, Empoli = 11.58
# Updated skills: Inter = 53.25, Genoa = 62.70
# Updated skills: Fiorentina = 34.07, Roma = 53.16
# Updated skills: Juventus = 322.90, Cagliari = -62.94
# Updated skills: Lazio = 42.15, Spal = 7.07
# Updated skills: Sampdoria = -46.75, Torino = 244.20
# Updated skills: Parma = -55.72, Frosinone = -203.61
# Updated skills: Chievo = -236.68, Sassuolo = 142.88
# Updated skills: Bologna = -144.43, Atalanta = 160.71
# Updated skills: Udinese = -104.26, Milan = 138.70
# Updated skills: Frosinone = -322.45, Fiorentina = 152.91
# Updated skills: Torino = 243.99, Parma = -55.50
# Updated skills: Spal = 6.19, Cagliari = -62.06
# Updated skills: Genoa = 52.89, Napoli = 90.82
# Updated skills: Atalanta = 214.45, Inter = -0.49
# Updated skills: Roma = 103.11, Sampdoria = -96.70
# Updated skills: Empoli = 69.51, Udinese = -162.19
# Updated skills: Chievo = -282.80, Bologna = -98.31
# Updated skills: Sassuolo = 142.25, Lazio = 42.78
# Updated skills: Milan = 46.60, Juventus = 415.00
# Updated skills: Udinese = -161.94, Roma = 102.87
# Updated skills: Juventus = 619.41, Spal = -198.22
# Updated skills: Inter = 160.49, Frosinone = -483.43
# Updated skills: Parma = -55.18, Sassuolo = 141.93
# Updated skills: Napoli = 90.65, Chievo = -282.63
# Updated skills: Empoli = 69.95, Atalanta = 214.01
# Updated skills: Bologna = -223.91, Fiorentina = 278.51
# Updated skills: Lazio = 37.48, Milan = 51.90
# Updated skills: Genoa = 52.46, Sampdoria = -96.27
# Updated skills: Cagliari = -215.09, Torino = 397.01
# Updated skills: Spal = -332.30, Empoli = 204.03
# Updated skills: Fiorentina = 108.06, Juventus = 789.86
# Updated skills: Sampdoria = -32.45, Bologna = -287.73
# Updated skills: Milan = 105.44, Parma = -108.72
# Updated skills: Torino = 569.29, Genoa = -119.81
# Updated skills: Sassuolo = 141.72, Udinese = -161.73
# Updated skills: Frosinone = -617.60, Cagliari = -80.91
# Updated skills: Chievo = -442.68, Lazio = 197.53
# Updated skills: Roma = 74.06, Inter = 189.31
# Updated skills: Atalanta = 213.49, Napoli = 91.16
# Updated skills: Juventus = 1090.13, Inter = -110.97
# Updated skills: Napoli = 445.54, Frosinone = -971.98
# Updated skills: Cagliari = -158.40, Roma = 151.54
# Updated skills: Lazio = 197.25, Sampdoria = -32.17
# Updated skills: Sassuolo = 140.10, Fiorentina = 109.69
# Updated skills: Udinese = -349.35, Atalanta = 401.10
# Updated skills: Parma = -108.91, Chievo = -442.49
# Updated skills: Empoli = 449.91, Bologna = -533.61
# Updated skills: Genoa = -120.12, Spal = -332.00
# Updated skills: Milan = -126.49, Torino = 801.22
# Updated skills: Inter = 8.22, Udinese = -468.53
# Updated skills: Torino = 656.76, Juventus = 1234.59
# Updated skills: Spal = -332.57, Chievo = -441.92
# Updated skills: Sampdoria = 6.20, Parma = -147.28
# Updated skills: Frosinone = -1528.01, Sassuolo = 696.13
# Updated skills: Fiorentina = 109.88, Empoli = 449.72
# Updated skills: Cagliari = -460.37, Napoli = 747.51
# Updated skills: Roma = 287.38, Genoa = -255.95
# Updated skills: Atalanta = 503.03, Lazio = 95.32
# Updated skills: Bologna = -737.17, Milan = 77.07
# Updated skills: Lazio = 373.17, Cagliari = -738.22
# Updated skills: Udinese = -468.59, Frosinone = -1527.95
# Updated skills: Sassuolo = 694.69, Torino = 658.20
# Updated skills: Napoli = 1287.55, Spal = -872.61
# Updated skills: Milan = 60.64, Fiorentina = 126.31
# Updated skills: Genoa = -255.86, Atalanta = 502.95
# Updated skills: Empoli = 449.57, Sampdoria = 6.34
# Updated skills: Parma = -147.39, Bologna = -737.07
# Updated skills: Chievo = -666.98, Inter = 233.29
# Updated skills: Juventus = 1708.19, Roma = -186.23
# Updated skills: Frosinone = -2322.25, Milan = 854.93
# Updated skills: Sampdoria = 343.01, Chievo = -1003.65
# Updated skills: Fiorentina = 126.08, Parma = -147.15
# Updated skills: Cagliari = -738.08, Genoa = -256.00
# Updated skills: Bologna = -1292.18, Lazio = 928.28
# Updated skills: Atalanta = -99.67, Juventus = 2310.81
# Updated skills: Torino = 762.51, Empoli = 345.26
# Updated skills: Spal = -1074.61, Udinese = -266.59
# Updated skills: Roma = -186.16, Sassuolo = 694.62
# Updated skills: Inter = 233.35, Napoli = 1287.49
# Updated skills: Juventus = 3294.72, Sampdoria = -640.90
# Updated skills: Udinese = -30.84, Cagliari = -973.83
# Updated skills: Sassuolo = 694.54, Atalanta = -99.59
# Updated skills: Parma = -148.60, Roma = -184.71
# Updated skills: Lazio = 927.90, Torino = 762.90
# Updated skills: Genoa = -447.03, Fiorentina = 317.11
# Updated skills: Empoli = 344.70, Inter = 233.91
# Updated skills: Chievo = -344.34, Frosinone = -2981.55
# Updated skills: Napoli = 2577.32, Bologna = -2582.02
# Updated skills: Milan = 1819.70, Spal = -2039.38
# Updated skills: Roma = -184.64, Torino = 762.83
# Updated skills: Udinese = -31.38, Parma = -148.07
# Updated skills: Inter = 3.60, Sassuolo = 924.85
# Updated skills: Frosinone = -4422.53, Atalanta = 1341.38
# Updated skills: Spal = -2039.50, Bologna = -2581.90
# Updated skills: Fiorentina = 317.05, Sampdoria = -640.83
# Updated skills: Cagliari = -1633.09, Empoli = 1003.96
# Updated skills: Napoli = 3402.03, Lazio = 103.19
# Updated skills: Genoa = -1580.40, Milan = 2953.07
# Updated skills: Juventus = 5114.25, Chievo = -2163.88
# Updated skills: Sassuolo = 2203.83, Cagliari = -2912.06
# Updated skills: Sampdoria = -640.73, Udinese = -31.49
# Updated skills: Milan = 2728.59, Napoli = 3626.51
# Updated skills: Chievo = -3404.34, Fiorentina = 1557.51
# Updated skills: Parma = -148.10, Spal = -2039.47
# Updated skills: Bologna = -2581.93, Frosinone = -4422.49
# Updated skills: Atalanta = 1341.34, Roma = -184.60
# Updated skills: Torino = 1142.44, Inter = -376.02
# Updated skills: Lazio = -2402.34, Juventus = 7619.78
# Updated skills: Empoli = 1003.93, Genoa = -1580.38
# Updated skills: Empoli = 1003.92, Chievo = -3404.32
# Updated skills: Napoli = 5760.13, Sampdoria = -2774.34
# c:\Users\Berhane\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_continuous_distns.py:10149: RuntimeWarning: invalid value encountered in power
#   g1 = mu3 / np.power(mu2, 1.5)
# Updated skills: Juventus = 7619.77, Parma = -148.09
# Updated skills: Spal = -3630.42, Torino = 2733.40
# Updated skills: Udinese = -825.98, Fiorentina = 2352.01
# Updated skills: Genoa = -3472.48, Sassuolo = 4095.93
# Updated skills: Inter = -376.04, Bologna = -2581.90
# Updated skills: Roma = -1641.19, Milan = 4185.18
# Updated skills: Frosinone = -5432.57, Lazio = -1392.27
# Updated skills: Cagliari = -5038.77, Atalanta = 3468.05
# Updated skills: Lazio = -1392.24, Empoli = 1003.89
# Updated skills: Chievo = -4285.89, Roma = -759.62
# Updated skills: Fiorentina = 647.95, Napoli = 7464.19
# Updated skills: Parma = -148.37, Inter = -375.76
# Updated skills: Bologna = -2581.97, Genoa = -3472.40
# Updated skills: Torino = 4513.09, Udinese = -2605.67
# Updated skills: Sampdoria = -2774.37, Frosinone = -5432.54
# Updated skills: Atalanta = 7017.28, Spal = -7179.66
# Updated skills: Sassuolo = 2334.01, Juventus = 9381.69
# Updated skills: Milan = 8797.16, Cagliari = -9650.74
# Updated skills: Juventus = 16788.81, Frosinone = -12839.66
# Updated skills: Cagliari = -9650.74, Parma = -148.38
# Updated skills: Atalanta = 6127.34, Milan = 9687.10
# Updated skills: Spal = -11093.46, Fiorentina = 4561.75
# Updated skills: Udinese = -1765.57, Chievo = -5126.00
# Updated skills: Genoa = -3472.37, Lazio = -1392.27
# Updated skills: Empoli = 1003.94, Sassuolo = 2333.96
# Updated skills: Inter = 823.54, Sampdoria = -3973.67
# Updated skills: Napoli = 7464.17, Torino = 4513.11
# Updated skills: Roma = 151.55, Bologna = -3493.15
# Updated skills: Milan = 14028.68, Empoli = -3337.64
# Updated skills: Torino = 4513.15, Atalanta = 6127.30
# Updated skills: Frosinone = -19335.26, Roma = 6647.16
# Updated skills: Sampdoria = -1135.14, Cagliari = -12489.27
# Updated skills: Sassuolo = 2333.95, Spal = -11093.46
# Updated skills: Chievo = -5952.81, Genoa = -2645.56
# Updated skills: Bologna = -13634.13, Juventus = 26929.79
# Updated skills: Parma = -3954.65, Napoli = 11270.44
# Updated skills: Fiorentina = 4561.73, Inter = 823.56
# Updated skills: Cagliari = -12489.27, Inter = 823.55
# Updated skills: Empoli = -3337.75, Parma = -3954.55
# Updated skills: Milan = 19876.04, Sassuolo = -3513.41
# Updated skills: Lazio = -1392.26, Roma = 6647.15
# Updated skills: Torino = 9746.14, Chievo = -11185.79
# Updated skills: Udinese = 4168.71, Bologna = -19568.41
# Updated skills: Spal = -16072.61, Sampdoria = 3844.02
# Updated skills: Genoa = -2645.56, Frosinone = -19335.26
# Updated skills: Atalanta = 6910.08, Fiorentina = 3778.95
# Updated skills: Napoli = 3440.77, Juventus = 34759.46
# Updated skills: Juventus = 50054.83, Udinese = -11126.66
# Updated skills: Parma = -3954.50, Genoa = -2645.61
# Updated skills: Chievo = -26716.71, Milan = 35406.96
# Updated skills: Bologna = -19568.40, Cagliari = -12489.27
# Updated skills: Sampdoria = 2310.99, Atalanta = 8443.12
# Updated skills: Inter = 9271.63, Spal = -24520.70
# Updated skills: Frosinone = -33875.95, Torino = 24286.83
# Updated skills: Sassuolo = -6990.50, Napoli = 6917.85
# Updated skills: Fiorentina = 3778.93, Lazio = -1392.25
# Updated skills: Roma = 11639.59, Empoli = -8330.19
# Updated skills: Cagliari = -12489.27, Fiorentina = 3778.93
# Updated skills: Sassuolo = -11641.25, Sampdoria = 6961.74
# Updated skills: Spal = -24520.70, Roma = 11639.59
# Updated skills: Torino = 24286.83, Bologna = -19568.40
# Updated skills: Genoa = -2645.61, Juventus = 50054.83
# Updated skills: Lazio = -111.13, Parma = -5235.62
# Updated skills: Empoli = 4442.69, Frosinone = -46648.84
# Updated skills: Atalanta = 8443.11, Chievo = -26716.70
# Updated skills: Napoli = 15940.11, Udinese = -20148.91
# Updated skills: Milan = 35406.96, Inter = 9271.64
# Updated skills: Chievo = -33830.42, Cagliari = -5375.55
# Updated skills: Udinese = -20148.91, Genoa = -2645.62
# Updated skills: Juventus = 72860.90, Empoli = -18363.38
# Updated skills: Sampdoria = 6961.74, Milan = 35406.95
# Updated skills: Parma = -12074.99, Atalanta = 15282.48
# Updated skills: Roma = 9489.33, Napoli = 18090.37
# Updated skills: Frosinone = -57712.91, Spal = -13456.63
# Updated skills: Fiorentina = -6475.02, Torino = 34540.78
# Updated skills: Bologna = -19568.39, Sassuolo = -11641.25
# Updated skills: Inter = 9271.63, Lazio = -111.12
# Updated skills: Milan = 35406.95, Udinese = -20148.91
# Updated skills: Cagliari = -44493.78, Juventus = 111979.13
# Updated skills: Empoli = -18363.38, Napoli = 18090.37
# Updated skills: Torino = 48330.30, Sampdoria = -6827.78
# Updated skills: Spal = -13456.62, Lazio = -111.13
# Updated skills: Roma = 9489.33, Fiorentina = -6475.02
# Updated skills: Genoa = -8604.24, Inter = 15230.25
# Updated skills: Frosinone = -57712.91, Parma = -12074.99
# Updated skills: Sassuolo = -546.67, Chievo = -44925.00
# Updated skills: Atalanta = 32707.92, Bologna = -36993.83
# Updated skills: Parma = -42277.64, Torino = 78532.95
# Updated skills: Juventus = 150265.22, Milan = -2879.13
# Updated skills: Sampdoria = -14986.33, Roma = 17647.88
# Updated skills: Fiorentina = -6475.02, Frosinone = -57712.90
# Updated skills: Udinese = -20148.87, Empoli = -18363.42
# Updated skills: Cagliari = -44493.78, Spal = -13456.62
# Updated skills: Lazio = -111.27, Sassuolo = -546.52
# Updated skills: Inter = 6491.42, Atalanta = 41446.75
# Updated skills: Napoli = 18090.36, Genoa = -8604.24
# Updated skills: Bologna = -33028.24, Chievo = -48890.59
# Updated skills: Spal = -13456.62, Juventus = 150265.22
# Updated skills: Roma = 36546.26, Udinese = -39047.25
# Updated skills: Milan = -2879.11, Lazio = -111.30
# Updated skills: Torino = 78532.94, Cagliari = -44493.78
# Updated skills: Sassuolo = -546.52, Parma = -42277.64
# Updated skills: Sampdoria = -14986.32, Genoa = -8604.25
# Updated skills: Fiorentina = -6475.02, Bologna = -33028.24
# Updated skills: Chievo = -82381.07, Napoli = 51580.84
# Updated skills: Frosinone = -89815.07, Inter = 38593.58
# Updated skills: Atalanta = 41446.75, Empoli = -18363.41
# Updated skills: Lazio = 19356.68, Udinese = -58515.23
# Updated skills: Parma = -61976.90, Milan = 16820.15
# Updated skills: Udinese = -87499.58, Sassuolo = 28437.83
# Updated skills: Lazio = 19356.68, Chievo = -82381.07
# Updated skills: Genoa = -52172.84, Torino = 122101.54
# Updated skills: Empoli = -20816.81, Spal = -11003.23
# Updated skills: Cagliari = -21833.13, Frosinone = -112475.71
# Updated skills: Bologna = -33028.23, Sampdoria = -14986.32
# Updated skills: Juventus = 228635.33, Fiorentina = -84845.14
# Updated skills: Inter = 38593.55, Roma = 36546.29
# Updated skills: Napoli = 51580.84, Atalanta = 41446.75
# Updated skills: Bologna = -33028.23, Empoli = -20816.81
# Updated skills: Roma = 65736.00, Cagliari = -51022.85
# Updated skills: Inter = -56427.34, Juventus = 323656.22
# Updated skills: Frosinone = -194503.98, Napoli = 133609.11
# Updated skills: Spal = -11003.23, Genoa = -52172.84
# Updated skills: Chievo = -92583.15, Parma = -51774.81
# Updated skills: Sampdoria = -32157.82, Lazio = 36528.18
# Updated skills: Torino = 174742.23, Milan = -35820.54
# Updated skills: Atalanta = 105919.92, Udinese = -151972.75
# Updated skills: Fiorentina = -141486.62, Sassuolo = 85079.31
# Updated skills: Juventus = 323656.22, Torino = 174742.24
# Updated skills: Chievo = -133373.12, Spal = 29786.73
# Updated skills: Udinese = -199745.45, Inter = -8654.63
# Updated skills: Empoli = 39518.09, Fiorentina = -201821.53
# Updated skills: Sassuolo = 85079.30, Frosinone = -194503.97
# Updated skills: Parma = -61583.31, Sampdoria = -22349.33
# Updated skills: Lazio = 1832.30, Atalanta = 140615.79
# Updated skills: Genoa = -111127.26, Roma = 124690.43
# Updated skills: Napoli = 225925.09, Cagliari = -143338.82
# Updated skills: Milan = -35820.52, Bologna = -33028.25
# Updated skills: Atalanta = 266487.32, Genoa = -236998.79
# Updated skills: Cagliari = -215924.39, Lazio = 74417.87
# Updated skills: Fiorentina = -284822.03, Milan = 47179.98
# Updated skills: Torino = 219573.70, Sassuolo = 40247.83
# Updated skills: Sampdoria = -53283.04, Empoli = 70451.80
# Updated skills: Frosinone = -194503.98, Udinese = -199745.44
# Updated skills: Spal = -68282.44, Napoli = 323994.26
# Updated skills: Roma = 124690.43, Juventus = 323656.22
# Updated skills: Bologna = -18750.72, Parma = -75860.83
# Updated skills: Inter = 53704.61, Chievo = -195732.36
# Updated skills: Udinese = -199745.44, Spal = -68282.45
# Updated skills: Genoa = -247536.00, Cagliari = -205387.18
# Updated skills: Sassuolo = -1973.47, Roma = 166911.73
# Updated skills: Chievo = -266957.02, Sampdoria = 17941.62
# Updated skills: Parma = 28619.76, Fiorentina = -389302.62
# Updated skills: Empoli = 70451.80, Torino = 219573.70
# Updated skills: Milan = 168021.97, Frosinone = -315345.97
# Updated skills: Napoli = 459139.09, Inter = -81440.22
# Updated skills: Juventus = 323656.22, Atalanta = 266487.32
# Updated skills: Lazio = 74417.87, Bologna = -18750.72
# Updated skills: Frosinone = -339540.44, Chievo = -242762.54
# Updated skills: Bologna = -18750.71, Napoli = 459139.08
# Updated skills: Torino = 292151.62, Lazio = 1839.95
# Updated skills: Sampdoria = 17941.63, Juventus = 323656.22
# Updated skills: Spal = -186434.65, Milan = 286174.17
# Updated skills: Roma = 236057.71, Parma = -40526.22
# Updated skills: Inter = -81440.22, Empoli = 70451.80
# Updated skills: Fiorentina = -460185.94, Genoa = -176652.68
# Updated skills: Cagliari = -208208.05, Udinese = -196924.57
# Updated skills: Atalanta = 400717.72, Sassuolo = -136203.86
